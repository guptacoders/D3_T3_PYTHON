# %%
import requests, json

api_key = input('Enter your API key: ')
city = input('Enter the city name: ')
request_url =f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}"
response = requests.get(request_url)
coordinates = response.json()
print(coordinates)
lat= coordinates[0]['lat']
long = coordinates[0]['lon']
# Out:
# Enter your API key: 9b540ccd0d52f1b4a61173ad81a4cfd9
# Enter the city name: Mumbai
# [{'name': 'Mumbai', 'local_names': {'uk': 'Мумбаї', 'lt': 'Mumbajus', 'kn': 'ಮುಂಬೈ', 'ja': 'ムンバイ', 'fa': 'مومبای', 'zh': '孟买', 'es': 'Bombay', 'ru': 'Мумбаи', 'mr': 'मुंबई', 'he': 'מומבאי', 'oc': 'Mumbai', 'gu': 'મુંબઈ', 'ks': 'بَمبَے', 'th': 'มุมไบ', 'sk': 'Bombaj', 'ps': 'ممبای', 'ml': 'മുംബൈ', 'eo': 'Mumbajo', 'yi': 'מומביי', 'bn': 'মুম্বই', 'hi': 'मुंबई', 'de': 'Mumbai', 'te': 'ముంబై', 'io': 'Mumbai', 'si': 'මුම්බායි', 'ka': 'მუმბაი', 'ur': 'ممبئی', 'ko': '뭄바이', 'ta': 'மும்பை', 'ia': 'Mumbai', 'el': 'Μουμπάι', 'fr': 'Bombay', 'sr': 'Мумбај', 'pl': 'Mumbaj', 'sd': 'ممبئي', 'cs': 'Bombaj', 'ar': 'مومباي', 'az': 'Mumbay', 'or': 'ମୁମ୍ବାଇ', 'en': 'Mumbai', 'pa': 'ਮੁੰਬਈ'}, 'lat': 19.0785451, 'lon': 72.878176, 'country': 'IN', 'state': 'Maharashtra'}]

# %%
api_key = input('Enter your API key: ')
request_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={long}&appid={api_key}"
response = requests.get(request_url)
current_weather = response.json()
print(json.dumps(current_weather, indent = 5))
# Out:
# Enter your API key: 9b540ccd0d52f1b4a61173ad81a4cfd9
# {
#      "coord": {
#           "lon": 72.8777,
#           "lat": 19.076
#      },
#      "weather": [
#           {
#                "id": 804,
#                "main": "Clouds",
#                "description": "overcast clouds",
#                "icon": "04d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 304.03,
#           "feels_like": 311.03,
#           "temp_min": 304.03,
#           "temp_max": 304.03,
#           "pressure": 1001,
#           "humidity": 76,
#           "sea_level": 1001,
#           "grnd_level": 999
#      },
#      "visibility": 10000,
#      "wind": {
#           "speed": 5.12,
#           "deg": 259,
#           "gust": 5.9
#      },
#      "clouds": {
#           "all": 98
#      },
#      "dt": 1748502337,
#      "sys": {
#           "country": "IN",
#           "sunrise": 1748478644,
#           "sunset": 1748526083
#      },
#      "timezone": 19800,
#      "id": 8131499,
#      "name": "Konkan Division",
#      "cod": 200
# }

# %%
quality_indices = {1:'Good', 2:'Fair', 3:'Moderate', 4:'Poor', 5:'Very Poor'}
def display_current_air_pollution():
 api_key = input('Enter your API key: ')
 request_url =f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={long}&appid={api_key}"
 response = requests.get(request_url)
 current_pollution = response.json()
 print(json.dumps(current_pollution, indent = 5))
 index = current_pollution['list'][0]['main']['aqi']
 print('Current Air Quality: ', quality_indices[index])
display_current_air_pollution()
# Out:
# Enter your API key: 9b540ccd0d52f1b4a61173ad81a4cfd9
# {
#      "coord": {
#           "lon": 72.8777,
#           "lat": 19.076
#      },
#      "list": [
#           {
#                "main": {
#                     "aqi": 2
#                },
#                "components": {
#                     "co": 82.56,
#                     "no": 0.01,
#                     "no2": 0.05,
#                     "o3": 44.17,
#                     "so2": 0.22,
#                     "pm2_5": 7.14,
#                     "pm10": 22.39,
#                     "nh3": 0.13
#                },
#                "dt": 1748502577
#           }
#      ]
# }
# Current Air Quality:  Fair

# %%
https://subslikescript.com/movie/Titanic-120338

# %%
import requests
from bs4 import BeautifulSoup
url="https://retail.onlinesbi.sbi/npersonal/"
result=requests.get(url)
content=result.text
soup=BeautifulSoup(content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="text/xhtml; charset=utf-8" http-equiv="Content-Type">
#    <title>
#     State Bank of India - Personal Banking
#    </title>
#    <link href="images/favicon.ico" rel="icon" type="image/x-icon"/>
#    <link href="css/bootstrap-5.2.3.min.css" rel="stylesheet"/>
#    <link href="css/styles_pb.css" rel="stylesheet" type="text/css"/>
#    <link href="fonts/fonticons/style.css" rel="stylesheet" type="text/css">
#     <script src="js/jquery-3.6.3.min.js" type="text/javascript">
#     </script>
#     <script src="js/bootstrap.bundle-5.2.3.min.js" type="text/javascript">
#     </script>
#     <script src="js/multilingual_pb.js" type="text/javascript">
#     </script>
#     <!-- multilingual.js -->
#     <!-- time delay -->
#     <script src="js/jsons/sbi_home.js" type="text/javascript">
#     </script>
#     <script src="js/jsons/header.js" type="text/javascript">
#     </script>
#     <script src="js/jsons/footer.js" type="text/javascript">
#     </script>
#     <script src="js/generic_pb.js" type="text/javascript">
#     </script>
#     <style id="styleCommon">
#      section .secContHeader {
# 		/* text-transform: uppercase;
# 		text-shadow: 2px 2px 4px rgba(0,0,0,0.35); */
# 	}
# 	section .secContHeader h1 {
# 		font-size: 2.2rem;
# 		/*font-weight: bold;*/
# 	}
# 	.flexCards {
# 		display: flex;
# 		flex-flow: row wrap;
# 		justify-content: center;
# 	}
# 	.flexCards .card {
# 		width: 260px;
# 		margin: 5px;
# 		font-size: 15px !important;
# 	}
# 	.secBgGray {
# 		background-color: var(--sbc-lite-01);
# 	}
#
#
# 	@media  (max-width: 1152px) {
# 		#secContProductsAndServices .flexCards .card {
# 			width: 220px;
# 		}
# 	}
# 	@media (max-width: 768px) {
# 		.flexCards .card,
# 		#secContProductsAndServices .flexCards .card {
# 			width: 300px;
# 		}
# 	}
# 	@media (max-width: 640px) {
# 		#secContProductsAndServices .flexCards .card {
# 			width: 98%;
# 		}
# 		#secContValuesAddedServices .flexCards .card {
# 			width: 46%;
# 		}
# 	}
# 	@media (max-width: 480px) {
# 		.flexCards .card {
# 			width: 100%;
# 		}
# 	}
# 	.flexCards .card-title {
# 		font-weight: bold;
# 		font-size: inherit;
# 		text-transform: uppercase;
# 		color: var(--sbc-yonograd3-purple);
# 	}
#
# 	#coreMenu {
# 	top: 278px !important;
# 	}
#     </style>
#     <style id="styleScrollMsgBar">
#      #secContScrollMessage {
# 	padding: 0 5px;
# }
# .scrollMsgBar {
# 	color: #280071;
# 	height: 30px;
# 	overflow: hidden;
# 	position: relative;
# 	/* background: #fefefe;
# 	background-color: var(--sbc-lite-01);
# 	*/
# }
# .scrollMsgBar .scrollMsgText {
# 	position: absolute;
# 	margin: 0;
# 	padding: 0;
# 	line-height: 30px;
# 	white-space: nowrap;
# 	font-size: .9rem;
# 	font-weight: bold;
# }
# .scrollMsgBar:hover .scrollMsgText {
# 	animation-play-state: paused !important;
# }
#     </style>
#     <!-- DO NOT DELETE -->
#     <style id="styleMarqueeAnim">
#     </style>
#     <!-- DO NOT DELETE -->
#     <style id="stylesUsefulLinks">
#      #secContUsefulLinks .linksGroup > div {
# 		min-height: 56px;
# 		margin-bottom: 2px;
# 		padding-left: 0;
# 		padding-right: 2px;
# 		padding-left: 10px;
# 		padding-right: 10px;
# 	}
# 	#secContUsefulLinks .linksGroup > div > a {
# 		display: flex;
# 		height: 100%;
# 		font-size: 0.96rem;
# 		color: var(--sbc-yonograd3-purple);
# 		text-decoration: none;
# 		background-color: white;
# 		align-items: center;
# 		justify-content: flex-start;
# 		border-radius: 0.2rem;
# 		line-height: 1.2;
# 		position: relative;
# 		overflow: hidden;
# 	}
# 	#secContUsefulLinks .linksGroup > div > a .icon {
# 		width: 24px !important;
# 		height: 24px;
# 		background: var(--sbc-yonograd3-purple-a1);
# 		border-radius: 50%;
# 		display: flex;
# 		justify-content: center;
# 		align-items: center;
# 		margin-left: 8px;
# 		margin-right: 6px;
# 	}
# 	#secContUsefulLinks .linksGroup > div > a .lbl {
# 		padding-right: 8px;
# 	}
#
# 	#secContUsefulLinks .linksGroup > div > a .icon,
# 	#secContUsefulLinks .linksGroup > div > a .lbl {
# 		position: relative;
# 		z-index: 1;
# 	}
# 	#secContUsefulLinks .linksGroup > div > a .icon:before {
# 		padding: 8px;
# 	}
# 	#secContUsefulLinks .linksGroup > div > a:hover {
# 		color: white;
# 		/*background-color: var(--sbc-yonograd3-purple);*/
# 	}
#
# 	#secContUsefulLinks .linksGroup a .bg {
# 		position: absolute;
# 		z-index: 0;
# 		left: 0;
# 		top: 0;
# 		width: 0;
# 		height: 100%;
# 		background: var(--sbc-yonograd);
# 		transition: width 0.2s ease-in-out;
# 	}
#
# 	#secContUsefulLinks .linksGroup a:hover .bg {
# 		width: 100%;
# 	}
# 	#secContUsefulLinks .linksGroup a:hover .icon{
# 		background-color: #ffffff33;
# 	}
#     </style>
#     <style id="styleCarouselQuickLinks">
#      /*
# 	@media (max-width: 576px) {
# 		#carouselQuickLinks .card-body {
# 			display: flex;
# 			justify-content: center;
# 		}
# 	}
# 	.multiCarBasePrev { opacity: 1; top: auto; bottom: -14px; }
# 	.multiCarBaseNext { opacity: 1; top: auto; bottom: -14px; }
#
# 	@media screen and (max-width: 575px) {
# 		.multiCarBasePrev { top: 0; bottom: 0; left: -10px; }
# 		.multiCarBaseNext { top: 0; bottom: 0; right: -10px; }
# 	}
# 	@media (min-width: 576px) and (max-width: 639px) {
# 		.multiCarBasePrev { left: 85.5%; }
# 		.multiCarBaseNext { right: 15px; }
# 	}
# 	@media (min-width: 640px) and (max-width: 767px) {
# 		.multiCarBasePrev { left: 87.5%; }
# 		.multiCarBaseNext { right: 15px; }
# 	}
# 	@media (min-width: 768px) and (max-width: 1023px) {
# 		.multiCarBasePrev { left: 88.5%; }
# 		.multiCarBaseNext { right: 15px; }
# 	}
# 	@media (min-width: 1024px) and (max-width: 1199px) {
# 		.multiCarBasePrev { left: 91.5%; }
# 		.multiCarBaseNext { right: 15px; }
# 	}
# 	@media (min-width: 1200px) and (max-width: 1365px) {
# 		.multiCarBasePrev { left: 92.5%; }
# 		.multiCarBaseNext { right: 15px; }
# 	}
# 	@media (min-width: 1366px) {
# 		.multiCarBasePrev { left: 93.5%; }
# 		.multiCarBaseNext { right: 15px; }
# 	}
#
# 	#carouselQuickLinks .carousel-item a .fipb {
# 		font-size: 56px;
# 		color: white;
# 		background: linear-gradient(-95deg, #FF2C47 -10%, #4A076A 70%, #280071 100%);
# 	}*/
#     </style>
#     <style id="styleQuickLinks">
#      .secContHeaderPartFirst{
# 	font-size: 2rem;
# 	color: var(--sbc-yonograd3-purple);
# 	font-weight: 800;
# }
# .secContHeaderPartSecnd {
# 	font-size: 1.5rem;
# 	color: var(--sbc-yonograd3-purple);
# 	font-weight: 500;
# }
# #secContQuickLinks .linksGroup {
# 	display: flex;
# 	flex-flow: row wrap;
# 	justify-content: center;
#
# }
# #secContQuickLinks .linksGroup .quicklinkWrap {
# 	padding: 0 8px;
# }
# @media (max-width: 575px) {
# 	#secContQuickLinks .linksGroup .quicklinkWrap {
# 		text-align: center;
# 	}
# }
#
#
# #secContQuickLinks .linksGroup a {
# 	display: flex;
# 	flex-direction: column;
# 	padding: 20px  0;
# 	height: 152px;
# 	color: var(--sbc-yono-blue);
# 	background-color: #fff;
# 	border-radius: 4px;
# 	border: 1px solid #e9ddff;
# 	cursor: pointer;
# 	box-shadow: 0px 0px 5px 1px var(--sbc-yonograd3-purple-a1);
# }
# #secContQuickLinks .linksGroup a:hover {
# 	color: var(--sbc-yono-blue);
# 	background-color: var(--sbc-yonograd2-purple-a1);
# }
#
# #secContQuickLinks .linksGroup a.multiCarBtnBase {
# 	background-color: transparent;
# 	border-color: transparent;
# 	box-shadow: none;
# }
# #secContQuickLinks .linksGroup a.multiCarBtnBase:hover {
# 	background-color: transparent;
# 	transition: .2s;
# }
# #secContQuickLinks .linksGroup a.multiCarBtnBase.carousel-control-prev {
# 	left: -2%;
# 	width: 5%;
# }
# #secContQuickLinks .linksGroup a.multiCarBtnBase.carousel-control-next {
# 	right: -2%;
# 	width: 5%;
# }
# #secContQuickLinks .linksGroup a .icon {
# 	font-size: 40px;
# 	height: 64px;
# 	padding-left: 10px;
# }
# #secContQuickLinks .linksGroup a .lbl {
# 	padding: 0px 20px;
# 	cursor: pointer;
# }
#
# @media (max-width: 575px) {
# #secContQuickLinks .linksGroup a{
#
# }
# #secContQuickLinks .linksGroup a.multiCarBtnBase.carousel-control-prev {
# 	left: 42%;
# 	width: 5%;
# 	top: 50%;
# }
# #secContQuickLinks .linksGroup a.multiCarBtnBase.carousel-control-next {
# 	right: 42%;
# 	width: 5%;
# 	top: 50%;
# }
#
#
# }
#     </style>
#     <style id="styleWhatsNew">
#      section#secContWhatsNew .secContHeader h1 {
# 	color: var(--sbc-whats-new);
# }
# #secContWhatsNew .linksGroup {
# 	columns: 3 300px;
# 	padding: 0 15px;
# }
# #secContWhatsNew .linksGroup a {
# 	display: flex;
# 	margin-bottom: 10px;
# 	background-color: #fff;
# 	overflow: hidden;
# 	align-items: center;
# 	position: relative;
# 	z-index: 0;
# 	border-radius: 5px;
# 	padding: 5px 0px;
# }
# #secContWhatsNew .linksGroup a .bg {
# 	position: absolute;
# 	z-index: 0;
# 	left: 0;
# 	top: 0;
# 	width: 0;
# 	height: 100%;
# 	background: var(--sbc-yonograd);
# 	transition: width 0.2s ease-in-out;
# }
# #secContWhatsNew .linksGroup a .svgIcon {
# 	display: flex;
# 	width: 40px;
# 	height: 40px;
# 	line-height: 40px;
# 	margin-left: -40px;
# 	fill: var(--sbc-yonograd3-purple-a5);
# 	display: none;
# }
# #secContWhatsNew .linksGroup a .icon {
# 	font-size: 52px;
# 	color: var(--sbc-yonograd3-purple);
# 	/* width: 120px; */
# 	/* height: 120px; */
# 	/* background-color: var(--sbc-yonograd1-red-a1); */
# 	background-color: transparent;
# 	display: flex;
# 	align-items: center;
# 	justify-content: center;
# }
# #secContWhatsNew .linksGroup a .lbl {
# 	display: flex;
# 	align-items: center;
# 	width: 100%;
# 	height: 40px;
# 	/* font-size: 14px; */
# 	line-height: 1.3;
# 	padding-left: 10px;
# 	padding-right: 10px;
# 	color: var(--sbc-yonograd3-purple);
# }
# #secContWhatsNew .linksGroup a .icon,
# #secContWhatsNew .linksGroup a .lbl {
# 	position: relative;
# 	z-index: 1;
# 	transition:  0.1s ease-in;
# 	cursor: pointer;
# }
#
# #secContWhatsNew .linksGroup a:hover .bg {
# 	width: 100%;
# }
# #secContWhatsNew .linksGroup a:hover .icon,
# #secContWhatsNew .linksGroup a:hover .lbl {
# 	color: white;
# }
#
# #secContWhatsNew .linksGroup a[rel="external]:hover .svgIcon.linkInternal,
# #secContWhatsNew .linksGroup a[target="_blank"]:hover .svgIcon.linkInternal  {
# 	display: none;
# }
# #secContWhatsNew .linksGroup a[rel="external]:hover .svgIcon.linkExternal,
# #secContWhatsNew .linksGroup a[target="_blank"]:hover .svgIcon.linkExternal  {
# 	visibility: visible;
# }
#     </style>
#     <style id="styleProductLinks">
#      #secContProductsAndServices .card {
# 	background-color: #fff;
# 	overflow: hidden;
# 	border: 1px solid #e9ddff;
# }
# #secContProductsAndServices .card-body {
# 	padding: var(--bs-card-spacer-y) 0;
# }
# #secContProductsAndServices .linksGroup {
# 	display: flex;
# 	flex-direction: column;
# }
# #secContProductsAndServices h6 {
# 	padding: 10px 15px;
# 	text-transform: uppercase;
# 	color: var(--sbc-color-05);
# 	font-weight: bold;
# }
#
# #secContProductsAndServices .linksGroup > a {
# 	display: flex;
# 	align-items: center;
# 	justify-content: space-between;
# 	color: var(--sbc-yonograd3-purple);
# 	text-decoration: none;
# 	padding: 8px 15px;
# 	border-bottom: 1px solid #e9ddff;
# 	transition: background-color 0.4s;
# 	position: relative;
# }
# #secContProductsAndServices .linksGroup a .bg {
# 	position: absolute;
# 	z-index: 0;
# 	left: 0;
# 	top: 0;
# 	width: 2px;
# 	height: 0;
# 	background: #280071;
# 	transition: 0.1s height ease-out, width 0.2s ease-out 0.1s;
# }
# #secContProductsAndServices .linksGroup > a:last-child {
# 	border-bottom-color: transparent;
# }
# #secContProductsAndServices .linksGroup > a:hover .bg {
# 	height: 100%;
# 	width: 100%;
# }
# #secContProductsAndServices .linksGroup > a .lbl,
# #secContProductsAndServices .linksGroup > a .symbol {
# 	position: relative;
# 	z-index: 1;
# 	transition: color 0.1s ease-in;
# 	cursor: pointer;
# 	line-height: initial;
# }
# #secContProductsAndServices .linksGroup > a:hover .lbl,
# #secContProductsAndServices .linksGroup > a:hover .symbol {
# 	color: white;
# }
#     </style>
#     <style id="styleValuesAddedServices">
#      #secContValuesAddedServices .card {
# 	border-color: transparent;
# }
# #secContValuesAddedServices .card > a {
# 	height: 100%;
# 	padding: 15px;
# 	color: var(--sbc-yonograd3-purple)!important;
# 	/* color: white !important; */
# 	background-color: #fff;
# 	/* background-color: var(--sbc-yonograd3-purple); */
# 	/* border: 2px dashed var(--sbc-yonograd3-purple); */
# 	border-radius: inherit;
# }
# #secContValuesAddedServices .card > a .card-body {
# 	padding: 0;
# 	display: flex;
# 	width: 100%;
# 	height: 100%;
# 	flex-direction: column;
# 	text-align: center;
# }
# #secContValuesAddedServices .card > a div[data-jsfn="blobBox"] {
# 	position: relative;
# 	height: 120px;
# }
# #secContValuesAddedServices .card > a div[data-jsfn="blobBox"] > * {
# 	position: absolute;
# 	left: 50%;
# 	top: 50%;
# 	transform: translate(-50%, -50%) scale(1.0);
# }
# #secContValuesAddedServices .card > a div[data-jsfn="blobBox"] .blobs {
# 	opacity: 0.1;
# 	transition: 0.2s ease-in 0s;
# 	transition-delay: 0s;
# }
# #secContValuesAddedServices .card > a div[data-jsfn="blobBox"] .blobs .blob {
# 	transition-property: all;
# 	transition-timing-function: linear;
# }
# #secContValuesAddedServices .card > a div[data-jsfn="blobBox"] .fipb {
# 	font-size: 60px;
# }
# #secContValuesAddedServices .card > a .card-body label {
# 	padding: 0;
# 	margin: 0;
# 	text-align: center;
# 	/* font-weight: bold; */
# 	font-size: inherit;
# 	display: block !important;
# }
#
# #secContValuesAddedServices .card > a:hover {
# 	background-color: white;
# }
# #secContValuesAddedServices .card > a:hover .card-body label {
# 	color: var(--sbc-yonograd3-purple);
# 	font-weight: bold;
# }
# #secContValuesAddedServices .card > a:hover div[data-jsfn="blobBox"] .blobs {
# 	transform: translate(-50%, -50%) scale(1.2);
# 	opacity: 1;
# 	transition-delay: 0.2s;
# }
# #secContValuesAddedServices .card > a:hover div[data-jsfn="blobBox"] .fipb {
#     color: #fff;
# 	transition-delay: 0.2s;
# }
#     </style>
#    </link>
#   </meta>
#  </head>
#  <body data-page="sbi_home">
#   <!-- Header -->
#   <header data-include="header">
#   </header>
#   <!-- Main Content -->
#   <main>
#    <!-- Section >>> Banner Carousel -->
#    <section id="secContBannerCarousel">
#     <div class="carousel slide" data-bs-interval="9000" data-bs-ride="carousel" id="homeBannerCarousel">
#      <div class="carousel-indicators d-flex customCIPos">
#      </div>
#      <div class="carousel-inner carousel-items">
#       <div class="carousel-item active">
#        <a class="" href="https://retail.onlinesbi.sbi/retail/login.htm">
#         <picture>
#          <source media="(min-width: 1200px)" srcset="images/banners/banner_1_eng_1920.jpg"/>
#          <source media="(min-width: 992px)" srcset="images/banners/banner_1_eng_1280.jpg"/>
#          <source media="(min-width: 768px)" srcset="images/banners/banner_1_eng_1152.jpg"/>
#          <source media="(max-width: 767px)" srcset="images/banners/banner_1_eng_800.jpg"/>
#          <img alt="responsive image" class="d-block img-fluid" srcset="images/banners/banner_1_eng_1920.jpg"/>
#         </picture>
#         <div class="carousel-caption justify-content-center align-items-center d-none">
#          <div>
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#      <!-- Left control -->
#      <a class="carousel-control-prev homeBannerNextPre" data-bs-slide="prev" href="#homeBannerCarousel">
#       <span class="carousel-control-prev-icon round">
#       </span>
#      </a>
#      <!-- Right control -->
#      <a class="carousel-control-next homeBannerNextPre" data-bs-slide="next" href="#homeBannerCarousel">
#       <span class="carousel-control-next-icon round">
#       </span>
#      </a>
#     </div>
#    </section>
#    <!-- Section >>> Horizontal Scrolling (Marquee) Text Message -->
#    <section id="secContScrollMessage">
#     <!-- <div class="scrollMsgBar" data-speed="80"> default 80 will be applied by the script -->
#     <div class="scrollMsgBar secBgGray">
#      <p class="scrollMsgText m-0 lang_html_00">
#      </p>
#     </div>
#    </section>
#    <!-- Section >>> Useful Links -->
#    <!--
# 				<div class="device-check visible-xs" data-device="xs"></div>
# 				<div class="device-check visible-sm" data-device="sm"></div>
# 				<div class="device-check visible-md" data-device="md"></div>
# 				<div class="device-check visible-lg" data-device="lg"></div>
# 			-->
#    <section class="pt-3 pb-5" id="secContUsefulLinks">
#     <div class="container-lg">
#      <div class="secContHeader text-center py-3">
#       <!-- <span class="fipbIcon fipb_"></span> -->
#       <span class="secContHeaderPartFirst">
#        Useful
#       </span>
#       <span class="secContHeaderPartSecnd">
#        Links
#       </span>
#      </div>
#      <div class="linksGroup row">
#       <!--
# 							<div class="col-12 col-sm-6 col-lg-3">
# 								<a class="" href="">
# 									<span class="icon fipb fipb_long-arrow-right"></span>
# 									<span class="lbl lang_html_">RBI Retail Direct portal</span>
# 								</a>
# 							</div>
# 						-->
#      </div>
#     </div>
#     <script id="jsUsefulLinks">
#      var usefulLinksInt = setInterval(function() {
# 					var navLinkSource = $('#navLinkSource');
# 					if( navLinkSource && window.loaded['header'] == true ) {
# 						var linkGroups = navLinkSource.find('.usefulLinks .linkGroup');
#
# 						linkGroups.each(function(ix, elt) {
# 							var div = $('<div class="col-12 col-sm-6 col-md-3"></div>');
# 							var linkGroup = $(elt).clone();
# 							var a = linkGroup.find('a'),
# 								icon = linkGroup.find('.icon'),
# 								lbl = linkGroup.find('.lbl'),
# 								bg = $('<div class="bg"></div>');
#
# 							a.append(bg), a.append(icon), a.append(lbl), div.append(a);
# 							$('#secContUsefulLinks .linksGroup').append(div);
# 						});
# 						//
# 						clearInterval( usefulLinksInt );
# 						//
# 					}
# 				}, 100);
#     </script>
#    </section>
#    <!-- Section >>> QuickLinks -->
#    <section class="secBgGray pt-3 pb-5" id="secContQuickLinks">
#     <div class="container-lg">
#      <div class="secContHeader text-center py-3">
#       <span class="secContHeaderPartFirst">
#        Quick
#       </span>
#       <span class="secContHeaderPartSecnd">
#        Links
#       </span>
#      </div>
#      <div class="linksGroup">
#       <div class="carousel slide carouselMultiSlides" data-bs-interval="4000" data-bs-ride="carousel" id="carouselQuickLinks">
#        <div class="carousel-inner d-flex" role="listbox">
#         <!--
# 								<div class="quicklinkWrap col-6 col-sm-4 col-lg-3 col-xl-2">
# 									<div class="card offerCustomCard offerCardBG0">
# 										<div class="card-body offersGradientBG"></div>
# 									</div>
# 								</div>
# 								-->
#        </div>
#        <a class="carousel-control-prev multiCarBtnBase" data-bs-slide="prev" href="#carouselQuickLinks" role="button">
#         <span aria-hidden="true" class="multiCarBtn">
#          <span class="fipb_long-arrow-left multiCarBtnIcon">
#          </span>
#         </span>
#        </a>
#        <a class="carousel-control-next multiCarBtnBase" data-bs-slide="next" href="#carouselQuickLinks" role="button">
#         <span aria-hidden="true" class="multiCarBtn">
#          <span class="fipb_long-arrow-right multiCarBtnIcon">
#          </span>
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#     <script id="jsContQuickLinks">
#      var quickLinksInt = setInterval(function() {
# 					var navLinkSource = $('#navLinkSource');
# 					if( navLinkSource && window.loaded['header'] == true ) {
# 						var linkGroups = navLinkSource.find('.quickLinks .linkGroup');
#
# 						linkGroups.each(function(ix0, elt0) {
# 							var linkGroup = $(elt0).clone();
# 							var active = (ix0 == 0) ? ' active' : '';
# 							var item = $('<div class="carousel-item' + active + '"></div>'),
# 								col = $('<div class="quicklinkWrap col-12 col-sm-6 col-md-4 col-lg-3"></div>'),
# 								a = linkGroup.find('a'),
# 								icon = linkGroup.find('.icon'),
# 								lbl = linkGroup.find('.lbl');
#
# 							a.append(icon), a.append(lbl), col.append(a), item.append(col);
# 							$('#carouselQuickLinks.carouselMultiSlides .carousel-inner').append(item);
# 						});
# 						//
# 						clearInterval( quickLinksInt );
# 						//
# 						createMultiCarouselMediaQuery( '#secContQuickLinks #carouselQuickLinks.carouselMultiSlides', [['min-width: 576px', 2], ['min-width: 768px', 3], ['min-width: 992px', 4], ['max-width: 576px', 1]] );
# 						createMultiSlideCarousel('#secContQuickLinks #carouselQuickLinks.carouselMultiSlides .carousel-item', 7);
# 					}
# 				}, 100);
#     </script>
#    </section>
#    <!-- Section >>> WhatsNew -->
#    <section class="pt-3 pb-5" id="secContWhatsNew">
#     <div class="container-lg">
#      <div class="secContHeader text-center py-3">
#       <!-- <span class="fipbIcon fipb_whatsNew"></span> -->
#       <span class="secContHeaderPartFirst">
#        Whats
#       </span>
#       <span class="secContHeaderPartSecnd">
#        New
#       </span>
#      </div>
#      <div class="linksGroup">
#       <!--
# 						<a class="" href="https://bank.sbi/web/yono/travel-holiday-deals" target="_blank">
# 							<div class="bg"></div>
# 							<span class="fipb fipb_holidaySavingAccount"></span>
# 							<label class="lang_text_001_31">SBI Holiday Savings Account</label>
# 						</a>
# 						 -->
#      </div>
#     </div>
#     <script id="jsContWhatsNew">
#      var whatsNewLinksInt = setInterval(function() {
# 					var navLinkSource = $('#navLinkSource');
# 					if( navLinkSource && window.loaded['header'] == true ) {
# 						var linkGroups = navLinkSource.find('.whatsNewLinks .linkGroup');
#
# 						linkGroups.each(function(ix0, elt0) {
# 							var linkGroup = $(elt0).clone();
#
# 							var a = linkGroup.find('a'),
# 								icon = linkGroup.find('.icon'),
# 								lbl = linkGroup.find('.lbl'),
# 								bg = $('<div class="bg"></div>'),
# 								svgExt = $('<svg class="svgIcon external"><use href="#svg-search" /></svg>'),
# 								svgInt = $('<svg class="svgIcon internal"><use href="#svg-phone" /></svg>');
#
# 							a.append(bg), a.append(svgExt), a.append(svgInt), a.append(icon), a.append(lbl);
# 							$('#secContWhatsNew .linksGroup').append(a);
# 						});
# 						//
# 						clearInterval( whatsNewLinksInt );
# 						//
# 					}
# 				}, 100);
#     </script>
#    </section>
#    <!-- Section >>> ProductsAndServices -->
#    <section class="secBgGray pt-3 pb-5" id="secContProductsAndServices">
#     <div class="container-xxl">
#      <div class="secContHeader text-center py-3">
#       <span class="secContHeaderPartFirst">
#        Products
#       </span>
#       <span class="secContHeaderPartSecnd">
#        and
#       </span>
#       <span class="secContHeaderPartFirst">
#        Services
#       </span>
#      </div>
#      <div class="flexCards">
#       <!--
# 						<div class="card">
# 							<img src="images/card-images/products/superfast-loans.jpg" class="card-img-top" alt="...">
# 							<div class="card-body">
# 								<h6 class="card-title lang_text_001_136">Others</h6>
#
# 								<div class="linksGroup">
# 									<a class="" href="https://www.onlinesbi.sbi/sbicollect/icollecthome.htm"  rel="external">
# 										<div class="bg"></div>
# 										<label class="lang_text_001_78">State Bank Collect</label>
# 										<span class="symbol">&rarr;</span>
# 									</a>
# 								</div>
# 							</div>
# 						</div>
# 						-->
#      </div>
#     </div>
#     <script id="jsContProductsAndServices">
#      var productCardsInt = setInterval(function() {
# 					var navLinkSource = $('#navLinkSource');
# 					if( navLinkSource && window.loaded['header'] == true ) {
# 						var productLinks = navLinkSource.find('.productLinks');
# 						productLinks.each(function(ix0, elt0) {
# 							var productLink = $(elt0).clone();
#
# 							var img = productLink.find('img'),
# 								h6 = productLink.find('h6'),
# 								linkGroups = productLink.find('.linkGroup');
#
# 							var card = $('<div class="card"></div>'),
# 								cardBody = $('<div class="card-body"></div>'),
# 								linksGroup = $('<div class="linksGroup"></div>');
#
# 							linkGroups.each(function(ix1, elt1) {
# 								var linkGroup = $(elt1);
#
# 								var a = linkGroup.find('a'),
# 									lbl = linkGroup.find('.lbl'),
# 									arrow = $('<span class="symbol">&rarr;</span>'),
# 									bg = $('<div class="bg"></div>');
#
# 								a.append(bg), a.append(lbl), a.append(arrow);
# 								linksGroup.append(a);
# 							});
#
# 							cardBody.append(h6), cardBody.append(linksGroup);
# 							card.append(img), card.append(cardBody);
#
# 							$('#secContProductsAndServices .flexCards').append(card);
# 						});
# 						//
# 						clearInterval( productCardsInt );
# 						//
# 					}
# 				}, 100);
#     </script>
#    </section>
#    <!-- Section >>> ValueAddedServices -->
#    <section class="pt-3 pb-5" id="secContValuesAddedServices">
#     <div class="container-xxl">
#      <div class="row">
#       <div class="secContHeader text-center py-3">
#        <!-- <span class="fipbIcon fipb_valueServices"></span> -->
#        <span class="secContHeaderPartFirst">
#         Value Added
#        </span>
#        <span class="secContHeaderPartSecnd">
#         Services
#        </span>
#       </div>
#       <div class="flexCards">
#        <!--
# 							<div class="card">
# 								<a class="" href="online_railway_tickets.html">
# 									<div class="card-body">
# 										<div data-jsfn="blobBox" data-jsfn-target=".card">
# 											<div class="blobs" style="width: 100px; height: 100px;">
# 												<div class="blob" style="position: absolute; left: 50%; top: 50%; transform-origin: center center; transition-duration: 876ms; background: var(--sbc-yonograd); border-radius: 55% 45% 38% 62% / 60% 39% 61% 40%; height: 92px; width: 85px; transform: translate(-50%, -50%) rotate(2deg);"></div>
# 											</div>
# 											<span class="fipb fipb_etickets"></span>
# 										</div>
# 										<label class="lang_text_001_84">E-tickets</label>
# 									</div>
# 								</a>
# 							</div>
# 							 -->
#       </div>
#      </div>
#     </div>
#     <script id="jsContValuesAddedServices">
#      var valueCardsInt = setInterval(function() {
# 					var navLinkSource = $('#navLinkSource');
# 					if( navLinkSource && window.loaded['header'] == true ) {
# 						var linkGroups = navLinkSource.find('.valueLinks .linkGroup');
#
# 						linkGroups.each(function(ix0, elt0) {
# 							var linkGroup = $(elt0).clone();
#
# 							var a = linkGroup.find('a'),
# 								icon = linkGroup.find('.icon'),
# 								lbl = linkGroup.find('.lbl');
#
# 							var card = $('<div class="card"></div>'),
# 								cardBody = $('<div class="card-body"></div>'),
# 								blobBox = $('<div data-jsfn="blobBox" data-jsfn-target=".card"><div class="blobs"></div></div>');
#
# 							blobBox.append(icon);
# 							cardBody.append(blobBox), cardBody.append(lbl);
# 							a.append(cardBody), card.append(a);
# 							$('#secContValuesAddedServices .flexCards').append(card);
# 						});
# 						// console.log( 'blobBoxes are created' );
# 						$('[data-jsfn="blobBox"]').createBlobs({ blobOptions: [{"background":"var(--sbc-grad-blob)"}] });
# 						//
# 						clearInterval( valueCardsInt );
# 						//
# 					}
# 				}, 100);
#     </script>
#    </section>
#   </main>
#   <!-- Footer -->
#   <footer data-include="footer">
#   </footer>
#   <!-- MODAL: View State Bank Rewardz Loyalty Points -->
#   <div class="modal fade" id="viewSBI_Rewards">
#    <div class="modal-dialog modal-xl modal-dialog-centered">
#     <div class="modal-content">
#      <!-- Modal Header -->
#      <div class="modal-header cusModHeder">
#       <h6 class="modal-title lang_text_001_121">
#        View State Bank Rewardz Loyalty Points
#       </h6>
#       <button class="btn-close modalBtn" data-bs-dismiss="modal" type="button">
#       </button>
#      </div>
#      <!-- Modal body -->
#      <div class="modal-body px-5 bulletList">
#       <p class="lang_text_001_122">
#        State Bank Rewardz is the Enterprise - wide Loyalty Program for all State Bank customers that awards them with Reward Points for various transactions across many banking services.
#       </p>
#       <p>
#        <span style="font-weight:bold; text-decoration:underline; color:#0065BB lang_text_001_123">
#         How it works
#        </span>
#        <br/>
#        <span class="lang_text_001_124">
#         At State Bank Rewardz, we believe that you must be rewarded whenever you make use of State Bank products or services. State Bank Rewardz will reward you in multiple ways that will get you your desired reward and /or service as fast as possible.
# 					  From shopping with your Debit Card to paying timely EMI for your loan, you earn Reward Points for a variety of transactions.
# 					  You then redeem, i.e. use your accumulated Reward Points to pay for a wide range of products &amp; services such as movie tickets,
# 					  air tickets, mobile/DTH recharge, apparel, electronics, home appliances and more.
#        </span>
#       </p>
#       <p class="h6 lang_text_001_125">
#        You can now view your Freedom Rewards Loyalty Points:
#       </p>
#       <ul>
#        <li class="cont-text-li lang_text_001_126">
#         <span style="font-weight:bold">
#          Step 1:
#         </span>
#         Logon to www.onlinesbi.sbi with your userid and password.
#        </li>
#        <li class="cont-text-li lang_text_001_127">
#         <span style="font-weight:bold">
#          Step 2:
#         </span>
#         Select 'Freedom Rewardz' under the 'My Accounts' tab. Two tabs are displayed 'Loyalty Points' and 'Statement'.  Default tab displayed is Loyalty Points.
#        </li>
#        <li class="cont-text-li lang_text_001_128">
#         <span style="font-weight:bold">
#          Step 3:
#         </span>
#         Details of your accounts are displayed in a tabular format under the heading - SB/CA/OD Account Number, Point Balance, Transactions.
#        </li>
#        <li class="cont-text-li lang_text_001_129">
#         <span style="font-weight:bold">
#          Step 4:
#         </span>
#         Corresponding to each account number, and point balance, a hyperlink 'Click here for last 10 transactions' is provided.  On clicking this link, the account summary for the last ten transactions is displayed containing details of the transaction like Date, Description, Earned Points and Redeemed Points.
#        </li>
#        <li class="cont-text-li lang_text_001_130">
#         <span style="font-weight:bold">
#          Step 5:
#         </span>
#         On clicking the 'Statement' tab, the details of your accounts in a tabular format under the heading - Account No / Nick Name, Account Type and Branch, is displayed.   When the radio button related to the corresponding account number is selected, the customer will be required to choose the date range of the statement required, and the appropriate options to download it from 'View', 'Download in Excel Format', 'Download in PDF format'.
#        </li>
#       </ul>
#      </div>
#      <!-- Modal footer -->
#      <div class="modal-footer d-none">
#       <button class="btn btn-light" data-bs-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- MODAL: Genuine Applications -->
#   <div class="modal fade" id="genuineApplication">
#    <div class="modal-dialog modal-xl modal-dialog-centered">
#     <div class="modal-content">
#      <!-- Modal Header -->
#      <div class="modal-header cusModHeder">
#       <h6 class="modal-title lang_text_001_100">
#        Genuine Applications
#       </h6>
#       <button class="btn-close modalBtn" data-bs-dismiss="modal" type="button">
#       </button>
#      </div>
#      <!-- Modal body -->
#      <div class="modal-body px-5 bulletList">
#       <p>
#        <em class="lang_text_001_101">
#         Use only our genuine applications available on popular application stores as detailed below to communicate with the Bank:
#        </em>
#       </p>
#       <h6 class="lang_text_001_102">
#        Google Play Store
#       </h6>
#       <ul>
#        <li class="cont-text-li lang_text_001_103">
#         <strong>
#          State Bank Anywhere - Associate Banks :
#         </strong>
#         Retail Internet Banking Application for the Users of State Bank Associate Banks -  SBBJ, SBH, SBM, SBP &amp; SBT.
#        </li>
#        <li class="cont-text-li lang_text_001_104">
#         <strong>
#          State Bank Anywhere :
#         </strong>
#         State Bank of India Retail Internet Banking Application available as separate applications in English and Hindi
#        </li>
#        <li class="cont-text-li lang_text_001_105">
#         <strong>
#          State Bank Freedom :
#         </strong>
#         State Bank of India Mobile Banking Application
#        </li>
#        <li class="cont-text-li lang_text_001_106">
#         <strong>
#          State Bank Secure :
#         </strong>
#         Software Token (Beta. Not for use by the general public.)
#        </li>
#        <li class="cont-text-li lang_text_001_107">
#         <strong>
#          SBI Finder :
#         </strong>
#         An Application to locate SBI Branches, ATMs, e-Corners etc.
#        </li>
#        <li class="cont-text-li lang_text_001_108">
#         <strong>
#          SBI Bank Holiday Calendar :
#         </strong>
#         SBI Bank Holiday Calendar Application
#        </li>
#       </ul>
#       <h6 class="cont-text-li lang_text_001_109 mt-3">
#        Blackberry App World
#       </h6>
#       <ul>
#        <li class="cont-text-li lang_text_001_110">
#         <strong>
#          State Bank Anywhere :
#         </strong>
#         State Bank of India Retail Internet Banking Application available as separate applications in English and Hindi
#        </li>
#        <li class="cont-text-li lang_text_001_111">
#         No such application. However, Blackberry users may please visit the site
#         <a class="" href="https://mobile.onlinesbi.com/sbidownloader/DownloadApplication.action" target="_blank">
#          https://mobile.onlinesbi.com/sbidownloader/DownloadApplication.action
#         </a>
#         for downloading the official Mobile Banking Application "State Bank Freedom" after selecting the specific model number.
#        </li>
#       </ul>
#       <h6 class="cont-text-li lang_text_001_112 mt-3">
#        Windows Market Place
#       </h6>
#       <ul>
#        <li class="cont-text-li lang_text_001_113">
#         <strong>
#          State Bank Secure :
#         </strong>
#         Software Token (Beta. Not for use by the general public.)
#        </li>
#        <li class="cont-text-li lang_text_001_114">
#         Windows users may also visit the site
#         <a class="" href="https://mobile.onlinesbi.com/sbidownloader/DownloadApplication.action" target="_blank">
#          https://mobile.onlinesbi.com/sbidownloader/DownloadApplication.action
#         </a>
#         for downloading the official Mobile Banking Application "State Bank Freedom" after selecting the specific model number.
#        </li>
#       </ul>
#       <h6 class="cont-text-li lang_text_001_115 mt-3">
#        Apple App Store
#       </h6>
#       <ul>
#        <li class="cont-text-li lang_text_001_116">
#         <strong>
#          State Bank Anywhere :
#         </strong>
#         State Bank of India Retail Internet Banking Application available as separate applications in English and Hindi
#        </li>
#        <li class="cont-text-li lang_text_001_117">
#         <strong>
#          State Bank Freedom :
#         </strong>
#         State Bank of India Mobile Banking Application
#        </li>
#        <li class="cont-text-li lang_text_001_118">
#         <strong>
#          State Bank Secure :
#         </strong>
#         Software Token (Beta. Not for use by the general public.)
#        </li>
#        <li class="cont-text-li lang_text_001_119">
#         <strong>
#          SBI Finder :
#         </strong>
#         An Application to locate SBI Branches, ATMs, e-Corners etc.
#        </li>
#        <li class="cont-text-li lang_text_001_120">
#         <strong>
#          SBI Bank Holiday Calendar :
#         </strong>
#         SBI Bank Holiday Calendar Application
#        </li>
#       </ul>
#      </div>
#      <!-- Modal footer -->
#      <div class="modal-footer d-none">
#       <button class="btn btn-light" data-bs-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="jsBannerCarousel">
#    $(function() {
# 			setTimeout(function() {
# 				window.drawBannerCarousel(
# 												"#homeBannerCarousel",
# 												{bannerItems: ".carousel-inner",
# 												arrowButtons: ".homeBannerNextPre",
# 												indicators: ".carousel-indicators",
# 												indicatorsClass: "customCIPos",
# 												indicatorsOn: [true, 320]
# 												}
# 				);
# 			}, 10);
# 		});
#   </script>
#   <script id="jsScrollMsgBar">
#    $(function() {
# 			function resetMarquee() {
# 				var $smB = $('.scrollMsgBar');
# 				var animCss = '';
# 				$('style#styleMarqueeAnim').html();
#
# 				$smB.each(function(ix, el) {
# 				   var $bar = $(this);
# 				   var $txt = $bar.find('.scrollMsgText');
# 				   var bW = Math.round( $bar.outerWidth() );
#
# 				   $txt.css('left', bW+'px');
# 				   $txt.css('animation', '');
# 				});
# 			}
# 			//
# 			function configMarquee() {
# 				var $smB = $('.scrollMsgBar');
# 				var animCss = '';
# 				$('style#styleMarqueeAnim').html();
#
# 				$smB.each(function(ix, el) {
# 				   var $bar = $(this);
# 				   var speedFactor = $bar.data('speed');
# 				   var $txt = $bar.find('.scrollMsgText');
# 				   var bW = Math.round( $bar.outerWidth() );
# 				   var tW = Math.round( $txt.outerWidth() );
# 				   var speed = (bW + tW) / (speedFactor ? speedFactor : 80);
# 				   var animProp = 'scroll-left' + ix + ' ' + speed + 's linear infinite';
#
# 				   animCss += '@keyframes scroll-left' + ix + ' {0% {left: ' +bW+'px;} 100% {left: ' +(tW * -1)+'px;} }\n';
# 				   $txt.css('animation', animProp);
# 				});
#
# 				$('style#styleMarqueeAnim').html( animCss );
# 			}
# 			//
# 			$('body').on('langDataUpdated', function() {
# 				resetMarquee();
# 				configMarquee();
# 			});
# 			//
# 			$(window).resize(function() {
# 				resetMarquee();
# 			});
# 			//
# 			setTimeout(function() {
# 				resetMarquee();
# 				configMarquee();
# 			}, 10);
# 		});
#   </script>
#  </body>
# </html>
# <script id="f5_cspm">
#  (function(){var f5_cspm={f5_p:'ILHJMLNFPGDDPIDHAMOIIMCHFKPPEDPGNDLALFBKAHBIKPLEHOPCIEHMBHKLBNEMFLDBHFNCAAEMPCNPKBDAMNNBAACEHFDPMHMJGMIHLJMNIFDLLIHIMJDBGHGNLDKN',setCharAt:function(str,index,chr){if(index>str.length-1)return str;return str.substr(0,index)+chr+str.substr(index+1);},get_byte:function(str,i){var s=(i/16)|0;i=(i&15);s=s*32;return((str.charCodeAt(i+16+s)-65)<<4)|(str.charCodeAt(i+s)-65);},set_byte:function(str,i,b){var s=(i/16)|0;i=(i&15);s=s*32;str=f5_cspm.setCharAt(str,(i+16+s),String.fromCharCode((b>>4)+65));str=f5_cspm.setCharAt(str,(i+s),String.fromCharCode((b&15)+65));return str;},set_latency:function(str,latency){latency=latency&0xffff;str=f5_cspm.set_byte(str,40,(latency>>8));str=f5_cspm.set_byte(str,41,(latency&0xff));str=f5_cspm.set_byte(str,35,2);return str;},wait_perf_data:function(){try{var wp=window.performance.timing;if(wp.loadEventEnd>0){var res=wp.loadEventEnd-wp.navigationStart;if(res<60001){var cookie_val=f5_cspm.set_latency(f5_cspm.f5_p,res);window.document.cookie='f5avr0352318045aaaaaaaaaaaaaaaa_cspm_='+encodeURIComponent(cookie_val)+';path=/;'+'';}
# return;}}
# catch(err){return;}
# setTimeout(f5_cspm.wait_perf_data,100);return;},go:function(){var chunk=window.document.cookie.split(/\s*;\s*/);for(var i=0;i<chunk.length;++i){var pair=chunk[i].split(/\s*=\s*/);if(pair[0]=='f5_cspm'&&pair[1]=='1234')
# {var d=new Date();d.setTime(d.getTime()-1000);window.document.cookie='f5_cspm=;expires='+d.toUTCString()+';path=/;'+';';setTimeout(f5_cspm.wait_perf_data,100);}}}}
# f5_cspm.go();}());
# </script>
